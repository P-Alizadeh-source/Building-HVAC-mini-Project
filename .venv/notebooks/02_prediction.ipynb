# %% [markdown]
# # 2. Data-driven prediction
#
# Compare persistence, Linear Regression and Random Forest for next-hour indoor temperature.

# %%
import sys, os
sys.path.append('../src')
import matplotlib.pyplot as plt
from prediction import run

# %%
results,y_test,pred=run(720)
for name,m in results.items(): print(name, {k:round(v,3) for k,v in m.items()})

# %%
plt.figure(figsize=(10,4)); plt.plot(y_test.values,label='Actual'); plt.plot(pred['Random Forest'],label='Random Forest'); plt.xlabel('Test hour'); plt.ylabel('Indoor temperature [°C]'); plt.legend(); plt.grid(); plt.show()
